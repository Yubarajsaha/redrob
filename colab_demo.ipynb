# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": ["# 🤖 Redrob AI — Intelligent Candidate Ranker\n", "### Redrob Hackathon — Talent Acquisition Challenge\n"]
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["!pip install sentence-transformers pandas numpy scikit-learn plotly -q"],
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["!git clone https://github.com/Yubarajsaha/redrob.git\n", "%cd redrob"],
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["from google.colab import drive\n", "drive.mount('/content/drive')\n", "import shutil\n", "shutil.copy('/content/drive/MyDrive/redrob/candidates.jsonl', 'data/candidates.jsonl')\n", "print('Dataset loaded!')"],
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["!python src/precompute.py --candidates data/candidates.jsonl"],
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["!python src/rank.py --candidates data/candidates.jsonl --out output/submission.csv"],
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["!python validate_submission.py output/submission.csv"],
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["import pandas as pd\n", "df = pd.read_csv('output/submission.csv')\n", "print('\\n🏆 TOP 10 CANDIDATES\\n' + '='*80)\n", "for _, row in df.head(10).iterrows():\n", "    print(f\"Rank {int(row['rank'])}: {row['candidate_id']} (score={row['score']:.4f})\\n  {row['reasoning']}\\n\")"],
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": ["from google.colab import files\n", "files.download('output/submission.csv')\n", "print('Downloaded!')"],
      "execution_count": null,
      "outputs": []
    }
  ]
}
